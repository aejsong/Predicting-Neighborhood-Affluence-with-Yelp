# %% [markdown]
# ## This Notebook added a column of Average Adjusted Gross Income  to the Existing data

# %%
import pandas as pd

# %%
df= pd.read_csv('../data/master.csv')
del df['Unnamed: 0']
df.head()
# Out:
#                                             alias  \
# 0  重庆特色小面-chongqing-special-noodles-san-gabriel-3
# 1               重庆小面-best-noodle-house-rosemead-3
# 2  眞-jin-cook-authentic-korean-soul-food-glendale
# 3                 新湘好-xiang-cuisine-monterey-park
# 4               いざかや-おせん-izakaya-osen-los-angeles
#
#                           category           city                      id  \
# 0           ['noodles', 'chinese']    San Gabriel  mm6l24khOfXhKqn4pKVojA
# 1          ['noodles', 'szechuan']       Rosemead  DgXxBgUEvARu45x7RSgYRw
# 2                       ['korean']       Glendale  C5s9a_prs6TbH510Bt_sqQ
# 3                      ['chinese']  Monterey Park  5FzLCjOW6mqjlQE-wNsjQg
# 4  ['sushi', 'izakaya', 'seafood']    Los Angeles  us0WnDOySVXXXwCqs0AaCw
#
#     latitude   longitude  price  rating  review_count  zip_code
# 0  34.103070 -118.091840      1     4.0         204.0     91776
# 1  34.081182 -118.066226      1     4.0         141.0     91770
# 2  34.150364 -118.254602      2     4.5          64.0     91203
# 3  34.063719 -118.134591      2     4.5         113.0     91754
# 4  34.083192 -118.273245      2     4.5         656.0     90026

# %%
df['zip_code'].sort_values(ascending = True)
# Out:
# 15902    90000
# 24688    90000
# 20963    90001
# 20620    90001
# 25409    90001
#          ...
# 25115    93955
# 4642     95020
# 7762     96137
# 14755    97630
# 28439    98188
# Name: zip_code, Length: 28545, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28545 entries, 0 to 28544
# Data columns (total 10 columns):
# alias           28545 non-null object
# category        28545 non-null object
# city            28545 non-null object
# id              28545 non-null object
# latitude        28545 non-null float64
# longitude       28545 non-null float64
# price           28545 non-null int64
# rating          28545 non-null float64
# review_count    28545 non-null float64
# zip_code        28545 non-null int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 2.2+ MB

# %%
df.isnull().sum()
# Out:
# alias           0
# category        0
# city            0
# id              0
# latitude        0
# longitude       0
# price           0
# rating          0
# review_count    0
# zip_code        0
# dtype: int64

# %%
df['zip_code'].unique()
# Out:
# array([91776, 91770, 91203, 91754, 90026, 90027, 90401, 90720, 91711,
#        90042, 90004, 90041, 91741, 90650, 91722, 90602, 90265, 90301,
#        91801, 90058, 90071, 90069, 91784, 90045, 90740, 91326, 90803,
#        92821, 91601, 90621, 90034, 91206, 91502, 91101, 90280, 90805,
#        91723, 90020, 90291, 90032, 91321, 90266, 90013, 91361, 91335,
#        91324, 91768, 90603, 90038, 90606, 90802, 91710, 91773, 90012,
#        90703, 91214, 91377, 90064, 90024, 91006, 91020, 90049, 90039,
#        90503, 90277, 90638, 90660, 90712, 91411, 91356, 91355, 91106,
#        91602, 90640, 90046, 90025, 91205, 91504, 90254, 90033, 90015,
#        90250, 90221, 91786, 90242, 91606, 90232, 90003, 90501, 90405,
#        91401, 90021, 90022, 90006, 91745, 90211, 91803, 91733, 93550,
#        91706, 91331, 91505, 90035, 90716, 91789, 91755, 90504, 91731,
#        91766, 90605, 91405, 91342, 91040, 91344, 90731, 90293, 91605,
#        91763, 90270, 90262, 90065, 90066, 90023, 90808, 91744, 91746,
#        90623, 91202, 90240, 91724, 91351, 91306, 91301, 90036, 90005,
#        90249, 91024, 90028, 91105, 91307, 91740, 90302, 91010, 91790,
#        91765, 90010, 90057, 90044, 93534, 90029, 90247, 90037, 90007,
#        91780, 91352, 90713, 91402, 90670, 90011, 91340, 91748, 90019,
#        90723, 93552, 91325, 91016, 90095, 90806, 90031, 90260, 90304,
#        90255, 91204, 90230, 90016, 90220, 90040, 91311, 90745, 91303,
#        93551, 91108, 90746, 91423, 90210, 90701, 90505, 90732, 91762,
#        90292, 90008, 90067, 90017, 90807, 90815, 91750, 90631, 90303,
#        90248, 91316, 90241, 90630, 91506, 91702, 91785, 91007, 91364,
#        90278, 90706, 91201, 91107, 91604, 90275, 90274, 90048, 90201,
#        90620, 91381, 90068, 93453, 90814, 91367, 91732, 90014, 90001,
#        91304, 90047, 90043, 91208, 91607, 90272, 91436, 91302, 90077,
#        91354, 91384, 90804, 90717, 92835, 91608, 90601, 91791, 91350,
#        91767, 91104, 91345, 90061, 90810, 93536, 93535, 91011, 90305,
#        90710, 90222, 92833, 90404, 91030, 91403, 90245, 90744, 90604,
#        90502, 90056, 91775, 91362, 91792, 91207, 91406, 91709, 93510,
#        90189, 90002, 90290, 91522, 91387, 90212, 91210, 92856, 90680,
#        90755, 90510, 93150, 90403, 91103, 90089, 91501, 91042, 93591,
#        91343, 90073, 91707, 90094, 91001, 90018, 90895, 90063, 90261,
#        90402, 90062, 90715, 92703, 91308, 90899, 91735, 92397, 92802,
#        93036, 90639, 93532, 91330, 92612, 90813, 93436, 90209, 92707,
#        92780, 92602, 92801, 92336, 90831, 91521, 90840, 91390, 91209,
#        91749, 92701, 90263, 92392, 92841, 93560, 92843, 90059, 91764,
#        90052, 92407, 95020, 91407, 92706, 92832, 93543, 90407, 93243,
#        90747, 92092, 92823, 91357, 91312, 96137, 90651, 92621, 92804,
#        92626, 90312, 91366, 90609, 90633, 91125, 91404, 91066, 93063,
#        91778, 91804, 92822, 92647, 90101, 90822, 91507, 90009, 91328,
#        91337, 90801, 91759, 91003, 90846, 93010, 91310, 92345, 93553,
#        91701, 90060, 97630, 90079, 91102, 90000, 93004, 90421, 92704,
#        93033, 92081, 91199, 92501, 91769, 92649, 91031, 92692, 91322,
#        91109, 91520, 91433, 90078, 91371, 91012, 92805, 92806, 91329,
#        91787, 92683, 92651, 91747, 92627, 92606, 92886, 91353, 91023,
#        92334, 92660, 92820, 91309, 90711, 90637, 90506, 91124, 92807,
#        93955, 90707, 91788, 92056, 91617, 91399, 92845, 98188],
#       dtype=int64)

# %%
zip_list = df['zip_code'].unique().astype(int)

# %%
zip_list = zip_list.tolist()

# %%
irs = pd.read_csv('../data/IRSIncomeByZipCode.csv')
irs.head(10)
# Out:
#   STATE  ZIPCODE  Number of returns  Adjusted gross income (AGI)    Avg AGI  \
# 0    AL        0            2022380                    105089761  51.963410
# 1    AL    35004               4930                       255534  51.832454
# 2    AL    35005               3300                       128387  38.905152
# 3    AL    35006               1230                        58302  47.400000
# 4    AL    35007              11990                       643708  53.687073
# 5    AL    35010               8320                       378497  45.492428
# 6    AL    35014               1610                        67205  41.742236
# 7    AL    35016               7030                       329461  46.865007
# 8    AL    35019                930                        34909  37.536559
# 9    AL    35020               9970                       260241  26.102407
#
#    Number of returns with total income  Total income amount  Avg total income  \
# 0                              2022380            106420533         52.621433
# 1                                 4930               258024         52.337525
# 2                                 3300               129390         39.209091
# 3                                 1230                58585         47.630081
# 4                                11990               651350         54.324437
# 5                                 8320               382106         45.926202
# 6                                 1610                67885         42.164596
# 7                                 7030               333226         47.400569
# 8                                  930                35392         38.055914
# 9                                 9970               262475         26.326479
#
#    Number of returns with taxable income  Taxable income amount  \
# 0                                1468370               67850874
# 1                                   4020                 163859
# 2                                   2440                  70760
# 3                                    940                  36341
# 4                                   9280                 414878
# 5                                   5610                 226514
# 6                                   1180                  38277
# 7                                   5080                 204874
# 8                                    650                  19152
# 9                                   5520                 110968
#
#    Avg taxable income
# 0           46.208295
# 1           40.760945
# 2           29.000000
# 3           38.660638
# 4           44.706681
# 5           40.376827
# 6           32.438136
# 7           40.329528
# 8           29.464615
# 9           20.102899

# %%
irs['ZIPCODE'].dtype
# Out:
# dtype('int64')

# %%
zip_agi = irs.loc[irs['ZIPCODE'].isin(zip_list),['ZIPCODE','Avg AGI']]

# %%
zip_agi.columns = ['zip_code', 'ave_agi']

# %%
zip_agi
# Out:
#        zip_code    ave_agi
# 1410      90001  25.152933
# 1411      90002  24.410496
# 1412      90003  23.404622
# 1413      90004  59.128947
# 1414      90005  45.821128
# ...         ...        ...
# 2225      93955  42.714365
# 2432      95020  71.744969
# 2888      96137  52.742975
# 20348     97630  45.872683
# 26040     98188  43.717699
#
# [344 rows x 2 columns]

# %%
df
# Out:
#                                                 alias  \
# 0      重庆特色小面-chongqing-special-noodles-san-gabriel-3
# 1                   重庆小面-best-noodle-house-rosemead-3
# 2      眞-jin-cook-authentic-korean-soul-food-glendale
# 3                     新湘好-xiang-cuisine-monterey-park
# 4                   いざかや-おせん-izakaya-osen-los-angeles
# ...                                               ...
# 28540                             1-pico-santa-monica
# 28541                            1-oak-west-hollywood
# 28542                        1-fish-market-long-beach
# 28543                                  1-drink-walnut
# 28544                               1-buffet-lawndale
#
#                                  category            city  \
# 0                  ['noodles', 'chinese']     San Gabriel
# 1                 ['noodles', 'szechuan']        Rosemead
# 2                              ['korean']        Glendale
# 3                             ['chinese']   Monterey Park
# 4         ['sushi', 'izakaya', 'seafood']     Los Angeles
# ...                                   ...             ...
# 28540  ['newamerican', 'seafood', 'bars']    Santa Monica
# 28541              ['danceclubs', 'bars']  West Hollywood
# 28542                      ['fishnchips']      Long Beach
# 28543                          ['coffee']          Walnut
# 28544                         ['chinese']        Lawndale
#
#                            id   latitude   longitude  price  rating  \
# 0      mm6l24khOfXhKqn4pKVojA  34.103070 -118.091840      1     4.0
# 1      DgXxBgUEvARu45x7RSgYRw  34.081182 -118.066226      1     4.0
# 2      C5s9a_prs6TbH510Bt_sqQ  34.150364 -118.254602      2     4.5
# 3      5FzLCjOW6mqjlQE-wNsjQg  34.063719 -118.134591      2     4.5
# 4      us0WnDOySVXXXwCqs0AaCw  34.083192 -118.273245      2     4.5
# ...                       ...        ...         ...    ...     ...
# 28540  mkA3VH0RcJfN3k8gfdj04Q  34.006681 -118.491776      3     3.5
# 28541  NT-c9ch6FLq4a1l72jiIsA  34.090900 -118.388910      3     2.0
# 28542  d3GXq-tmY36ZPYUj9fb6Yw  33.854949 -118.185135      1     3.5
# 28543  pEG7qeAK--euth4PzOIwVA  34.043142 -117.850022      1     4.0
# 28544  jBjhNV9oQt9C9ioBCdznQw  33.900448 -118.351761      1     3.0
#
#        review_count  zip_code
# 0             204.0     91776
# 1             141.0     91770
# 2              64.0     91203
# 3             113.0     91754
# 4             656.0     90026
# ...             ...       ...
# 28540         294.0     90405
# 28541         286.0     90069
# 28542          29.0     90805
# 28543         204.0     91789
# 28544         185.0     90260
#
# [28545 rows x 10 columns]

# %%
df_income = pd.merge(df, zip_agi,how = 'outer' )
df_income
# Out:
#                                                 alias  \
# 0      重庆特色小面-chongqing-special-noodles-san-gabriel-3
# 1                          yung-ho-cafe-san-gabriel-2
# 2                             yun-nan-168-san-gabriel
# 3                            yum-cha-cafe-san-gabriel
# 4                          yuk-dae-jang-san-gabriel-2
# ...                                               ...
# 28540                                  baps-oceanside
# 28541                    bangkok-cafe-north-hollywood
# 28542                alborz-restaurant-woodland-hills
# 28543                 a-bite-of-jersey-garden-grove-2
# 28544                 5-guys-burger-and-fries-tukwila
#
#                                               category             city  \
# 0                               ['noodles', 'chinese']      San Gabriel
# 1         ['taiwanese', 'chinese', 'breakfast_brunch']      San Gabriel
# 2                                          ['chinese']      San Gabriel
# 3                                ['dimsum', 'hotdogs']      San Gabriel
# 4                                           ['korean']      San Gabriel
# ...                                                ...              ...
# 28540                                   ['foodstands']        Oceanside
# 28541                                         ['thai']  North Hollywood
# 28542                        ['mideastern', 'persian']   Woodland Hills
# 28543  ['cheesesteaks', 'sandwiches', 'chicken_wings']     Garden Grove
# 28544                                      ['burgers']          Tukwila
#
#                            id   latitude   longitude  price  rating  \
# 0      mm6l24khOfXhKqn4pKVojA  34.103070 -118.091840      1     4.0
# 1      zO8V4fi49QQMn4Sa_0OS9g  34.081429 -118.084785      1     3.0
# 2      6J_4QelYHplaLHzof1VEyg  34.080849 -118.090324      1     3.0
# 3      KD_fdBnwN3TbJYJ8mcvq4Q  34.078899 -118.092026      1     3.0
# 4      DwvljRkxkMEljQBYX-MeTw  34.102080 -118.109870      2     4.5
# ...                       ...        ...         ...    ...     ...
# 28540  FVBgAN591l9sljCHCsY1Rw  33.206660 -117.303090      2     4.0
# 28541  781cayN2BltvRW3-8FY87Q  34.179160 -118.404830      1     2.0
# 28542  t5M5X2TzaqxCStGxTH9odg  34.179350 -118.623720      2     4.0
# 28543  Gr4TtbfG10vmgOkFdnadYw  33.780935 -118.041427      1     4.0
# 28544  nLhg57UOPLgJhaGt1hTLlw  34.068906 -117.933201      2     3.0
#
#        review_count  zip_code    ave_agi
# 0             204.0     91776  37.211020
# 1             263.0     91776  37.211020
# 2               4.0     91776  37.211020
# 3             138.0     91776  37.211020
# 4             158.0     91776  37.211020
# ...             ...       ...        ...
# 28540           5.0     92056  57.641332
# 28541           2.0     91617        NaN
# 28542         227.0     91399        NaN
# 28543         161.0     92845  72.275806
# 28544           3.0     98188  43.717699
#
# [28545 rows x 11 columns]

# %%
df_income.isnull().sum()
# Out:
# alias             0
# category          0
# city              0
# id                0
# latitude          0
# longitude         0
# price             0
# rating            0
# review_count      0
# zip_code          0
# ave_agi         336
# dtype: int64

# %%
df_income[df_income.isnull().any(axis=1)]
# Out:
#                                      alias  \
# 2566                   zs-dtla-los-angeles
# 2567                     ziran-los-angeles
# 2568   water-grill-los-angeles-los-angeles
# 2569            wakana-sushi-los-angeles-3
# 2570                 trimana-los-angeles-6
# ...                                    ...
# 28535                cafe-aroma-pasadena-2
# 28538            bottoms-up-bar-bellflower
# 28539                     boba-time-walnut
# 28541         bangkok-cafe-north-hollywood
# 28542     alborz-restaurant-woodland-hills
#
#                                                 category             city  \
# 2566   ['breakfast_brunch', 'mediterranean', 'newamer...      Los Angeles
# 2567                                     ['newamerican']      Los Angeles
# 2568                                         ['seafood']      Los Angeles
# 2569                               ['japanese', 'sushi']      Los Angeles
# 2570                      ['tradamerican', 'sandwiches']      Los Angeles
# ...                                                  ...              ...
# 28535                                          ['cafes']         Pasadena
# 28538                          ['karaoke', 'sportsbars']       Bellflower
# 28539                    ['icecream', 'coffee', 'cafes']           Walnut
# 28541                                           ['thai']  North Hollywood
# 28542                          ['mideastern', 'persian']   Woodland Hills
#
#                            id   latitude   longitude  price  rating  \
# 2566   y4ZSoPCIqY7n-u3lqvtGBw  34.052221 -118.253950      2     4.0
# 2567   HUuiz9kpDi8i46mT4Yo2xA  34.054880 -118.255411      2     4.0
# 2568   pDqUvoNY1kR963MJnfnL6Q  34.049037 -118.254691      3     4.0
# 2569   zFR_UHWftwtPJdnEALw_aQ  34.052750 -118.255313      2     2.5
# 2570   wOipaUNwknfydMlIs1xGPw  34.051030 -118.254530      2     3.0
# ...                       ...        ...         ...    ...     ...
# 28535  J3lvauqozg6zZd0SAJcQhw  34.148598 -118.152374      1     3.0
# 28538  K66VTsqOIU3za6WBvD3uqQ  33.874593 -118.139790      1     3.5
# 28539  KdP7hy5sh_3rvhqjCPvgxw  33.986748 -117.869105      1     3.5
# 28541  781cayN2BltvRW3-8FY87Q  34.179160 -118.404830      1     2.0
# 28542  t5M5X2TzaqxCStGxTH9odg  34.179350 -118.623720      2     4.0
#
#        review_count  zip_code  ave_agi
# 2566           76.0     90071      NaN
# 2567           92.0     90071      NaN
# 2568         2029.0     90071      NaN
# 2569           19.0     90071      NaN
# 2570           18.0     90071      NaN
# ...             ...       ...      ...
# 28535           1.0     91124      NaN
# 28538         194.0     90707      NaN
# 28539         281.0     91788      NaN
# 28541           2.0     91617      NaN
# 28542         227.0     91399      NaN
#
# [336 rows x 11 columns]

# %%
df_income.dropna(inplace = True)

# %%
df_income.isnull().sum()
# Out:
# alias           0
# category        0
# city            0
# id              0
# latitude        0
# longitude       0
# price           0
# rating          0
# review_count    0
# zip_code        0
# ave_agi         0
# dtype: int64

# %%
df_income.groupby('zip_code')['zip_code'].count().head(30)
# Out:
# zip_code
# 90001     93
# 90002     21
# 90003     71
# 90004    155
# 90005    147
# 90006    221
# 90007    162
# 90008     56
# 90010    143
# 90011    104
# 90012    320
# 90013    197
# 90014    161
# 90015    219
# 90016     80
# 90017    177
# 90018     50
# 90019    161
# 90020    206
# 90021     99
# 90022    175
# 90023    119
# 90024    160
# 90025    230
# 90026    214
# 90027    199
# 90028    357
# 90029    136
# 90031     63
# 90032     66
# Name: zip_code, dtype: int64

# %%
df_income['count'] = df_income.groupby('zip_code')['zip_code'].transform('count')

# %%
df_income.to_csv('../data/data_income.csv')

# %%
df_to_save = df_income.pivot_table(index = ['zip_code'])

# %%
 df_to_save.to_csv('../data/data_zipcode.csv')
